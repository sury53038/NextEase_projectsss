# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# x = [1,2,3,4,5,6,7]
# y = [50,51,52,48,49,46,54]

# %%
# plt.plot(x,y,color = 'red', linewidth = 3, ls = 'dashed')
# plt.xlabel('Day')
# plt.ylabel('Temperature')
# plt.title('Weather')
# plt.show()

# %%
# plt.plot(x,y, 'rD--')
# plt.show()

# %%
# plt.plot(x,y, color = 'red', marker ='D', linestyle = ' ',markersize = 5)
# plt.show()

# %%
import numpy as np

# %%
company = ['GOOGLE', 'AMAZN', 'FLIPKART', 'MYNTRA']
revenue = [100, 200, 400, 250]
profit = [12, 23, 133, 28]

# %%
xpos = np.arange(len(company))
xpos
# Out:
# array([0, 1, 2, 3])

# %%
plt.xticks(ypos, company)
plt.bar(xpos-0.2, revenue,width = 0.4, label = "Revenue")
plt.bar(xpos+0.2, profit, width = 0.4, label = "Profit")
plt.legend()
plt.xlabel("COMPANIES")
plt.ylabel("REVENEUE($)")
plt.title("LEADING E-COMM")
plt.show()

# %%
blood_sugar = [99, 113, 83, 110, 110, 82, 92, 95, 106, 108,145,123,145,111]
blood_sugarw = [99, 103, 113, 111, 110, 182, 192, 90, 106,80, 108,145,123,145,111]

# %%
plt.hist([blood_sugar,blood_sugarw], bins = [80,100,125,200], rwidth =0.95, color = ['g', 'orange'],
        label=['men','women'], orientation='horizontal')
plt.legend()
plt.xlabel('Sugar Level')
plt.ylabel('Total no. of patients')
plt.title('Patient Sugar Report')
plt.show()

# %%
exp_vals = [1500, 1500, 1000, 1200, 800]
exp_labels = ['Electricity', 'Food', 'Phone', 'Car', 'Others']

# %%
plt.pie(exp_vals, labels = exp_labels, radius = 1.2,autopct='%0.0f%%', shadow = True, explode=[0,.1,0,0,0])
plt.show()

# %%
plt.savefig("piechart.png")
